# %% [markdown]
# # 4.4 Methods for Boolean Arrays

# %%
import numpy as np

# %% [markdown]
# Boolean values are coerced to `1` (True) and `0` (False) in the preceding methods. Thus, `sum` is often used as a means of counting `True` values in a boolean array.

# %%
rng = np.random.default_rng(seed=12345)
arr = rng.standard_normal(100)

# %%
# Count the number of positive values
print(f"Number of positive values: {(arr > 0).sum()}")
# Out:
# Number of positive values: 50

# %%
# Count the number of non-positive values
print(f"Number of non-positive values: {(arr <= 0).sum()}")
# Out:
# Number of non-positive values: 50

# %% [markdown]
# ## 4.4.1 `any` and `all`

# %% [markdown]
# Two additional methods, `any` and `all`, are useful especially for boolean arrays. `any` tests whether one or more values in an array is `True`, while `all` checks if every value is `True`.

# %%
bools = np.array([False, False, True, False])

# %%
# Check if any value is True
print(f"Any True? {bools.any()}")
# Out:
# Any True? True

# %%
# Check if all values are True
print(f"All True? {bools.all()}")
# Out:
# All True? False
